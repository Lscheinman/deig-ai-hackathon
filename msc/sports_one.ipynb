# %%
import requests
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
# API Configuration
url = 'https://s1-test-patch-publicsafety.test.sportsone.cloud.sap/external/export/med/v1/playerHealthPersons'
params = {'$top': '50'}

# Authentication credentials from environment variables
username = os.getenv('SPORTS_ONE_USERNAME')
password = os.getenv('SPORTS_ONE_PWORD')

# Make the API request
response = requests.get(
    url,
    params=params,
    auth=(username, password),
    headers={'accept': 'application/json'}
)

# Check response
print(f"Status Code: {response.status_code}")
if response.status_code == 200:
    data = response.json()
    print(f"Response: {data}")
else:
    print(f"Error: {response.text}")
# Out:
# Status Code: 200
# Response: {'@odata.context': '$metadata#playerHealthPersons', 'value': [{'AdditionalLastName': None, 'Alias': 'C1-PFV-2024-01', 'Birthday': None, 'Birthyear': 1988, 'ChangedAt': '2024-01-28T11:21:56.570Z', 'CreatedAt': '2024-01-28T11:21:56.570Z', 'Deceased': None, 'DeceasedOn': None, 'FirstName': 'Toni', 'Gender': 'male', 'GenderText': 'Male', 'LastName': 'C1-PFV-2024-01', 'LicenseNumber': None, 'MiddleName': None, 'NickName': None, 'PersonId': '066AE435079346D9BB75E38B36901822'}, {'AdditionalLastName': None, 'Alias': 'C1-2024-S02', 'Birthday': None, 'Birthyear': 1992, 'ChangedAt': '2024-01-29T12:17:00.273Z', 'CreatedAt': '2024-01-29T12:17:00.273Z', 'Deceased': None, 'DeceasedOn': None, 'FirstName': 'Detlev', 'Gender': 'male', 'GenderText': 'Male', 'LastName': 'C1-2024-S02', 'LicenseNumber': None, 'MiddleName': None, 'NickName': None, 'PersonId': '0E36D4A849744F3291309941F5C5270C'}, {'AdditionalLastName': None, 'Alias': 'C1-2024-S03', 'Birthday': None, 'Birthyear': 1993, 'ChangedAt': '2024-01-29T12:16:14.266Z', 'CreatedAt': '2024-01-29T12:16:14.266Z', 'Deceased': None, 'DeceasedOn': None, 'FirstName': 'Manni', 'Gender': 'male', 'GenderText': 'Male', 'LastName': 'C1-2024-S03', 'LicenseNumber': None, 'MiddleName': None, 'NickName': None, 'PersonId': '52833927FDD248BE9C579D72E9B0F176'}, {'AdditionalLastName': None, 'Alias': 'X-2023-05', 'Birthday': None, 'Birthyear': 1992, 'ChangedAt': '2024-01-28T11:08:04.786Z', 'CreatedAt': '2024-01-28T11:08:04.786Z', 'Deceased': None, 'DeceasedOn': None, 'FirstName': 'Mitch', 'Gender': 'male', 'GenderText': 'Male', 'LastName': 'X-2023-05', 'LicenseNumber': None, 'MiddleName': None, 'NickName': None, 'PersonId': '5D7BEB6F1EAA4334A0A1C61185676873'}, {'AdditionalLastName': None, 'Alias': 'C1-2024-S01', 'Birthday': None, 'Birthyear': 1997, 'ChangedAt': '2024-01-29T12:17:29.925Z', 'CreatedAt': '2024-01-29T12:17:29.925Z', 'Deceased': None, 'DeceasedOn': None, 'FirstName': 'Jürgen', 'Gender': 'male', 'GenderText': 'Male', 'LastName': 'C1-2024-S01', 'LicenseNumber': None, 'MiddleName': None, 'NickName': None, 'PersonId': '7143BF8C2FE44BF1ABDA10E3BAA33CCF'}, {'AdditionalLastName': None, 'Alias': 'L-2024-P005M', 'Birthday': None, 'Birthyear': 1997, 'ChangedAt': '2024-01-29T12:21:42.060Z', 'CreatedAt': '2024-01-29T12:21:42.060Z', 'Deceased': None, 'DeceasedOn': None, 'FirstName': 'André', 'Gender': 'male', 'GenderText': 'Male', 'LastName': 'L-2024-P005M', 'LicenseNumber': None, 'MiddleName': None, 'NickName': None, 'PersonId': '753D3E7DD7B646E3B44872301CF0754D'}, {'AdditionalLastName': None, 'Alias': 'C1-PFV-2024-02', 'Birthday': None, 'Birthyear': 1992, 'ChangedAt': '2024-01-28T11:22:29.914Z', 'CreatedAt': '2024-01-28T11:22:29.914Z', 'Deceased': None, 'DeceasedOn': None, 'FirstName': 'Chris', 'Gender': 'male', 'GenderText': 'Male', 'LastName': 'C1-PFV-2024-02', 'LicenseNumber': None, 'MiddleName': None, 'NickName': None, 'PersonId': 'C4502DE0576340419B5BEF056030E04D'}]}

# %%
data
# Out:
# {'@odata.context': '$metadata#playerHealthPersons',
#  'value': [{'AdditionalLastName': None,
#    'Alias': 'C1-PFV-2024-01',
#    'Birthday': None,
#    'Birthyear': 1988,
#    'ChangedAt': '2024-01-28T11:21:56.570Z',
#    'CreatedAt': '2024-01-28T11:21:56.570Z',
#    'Deceased': None,
#    'DeceasedOn': None,
#    'FirstName': 'Toni',
#    'Gender': 'male',
#    'GenderText': 'Male',
#    'LastName': 'C1-PFV-2024-01',
#    'LicenseNumber': None,
#    'MiddleName': None,
#    'NickName': None,
#    'PersonId': '066AE435079346D9BB75E38B36901822'},
#   {'AdditionalLastName': None,
#    'Alias': 'C1-2024-S02',
#    'Birthday': None,
#    'Birthyear': 1992,
#    'ChangedAt': '2024-01-29T12:17:00.273Z',
#    'CreatedAt': '2024-01-29T12:17:00.273Z',
#    'Deceased': None,
#    'DeceasedOn': None,
#    'FirstName': 'Detlev',
#    'Gender': 'male',
#    'GenderText': 'Male',
#    'LastName': 'C1-2024-S02',
#    'LicenseNumber': None,
#    'MiddleName': None,
#    'NickName': None,
#    'PersonId': '0E36D4A849744F3291309941F5C5270C'},
#   {'AdditionalLastName': None,
#    'Alias': 'C1-2024-S03',
#    'Birthday': None,
#    'Birthyear': 1993,
#    'ChangedAt': '2024-01-29T12:16:14.266Z',
#    'CreatedAt': '2024-01-29T12:16:14.266Z',
#    'Deceased': None,
#    'DeceasedOn': None,
#    'FirstName': 'Manni',
#    'Gender': 'male',
#    'GenderText': 'Male',
#    'LastName': 'C1-2024-S03',
#    'LicenseNumber': None,
#    'MiddleName': None,
#    'NickName': None,
#    'PersonId': '52833927FDD248BE9C579D72E9B0F176'},
#   {'AdditionalLastName': None,
#    'Alias': 'X-2023-05',
#    'Birthday': None,
#    'Birthyear': 1992,
#    'ChangedAt': '2024-01-28T11:08:04.786Z',
#    'CreatedAt': '2024-01-28T11:08:04.786Z',
#    'Deceased': None,
#    'DeceasedOn': None,
#    'FirstName': 'Mitch',
#    'Gender': 'male',
#    'GenderText': 'Male',
#    'LastName': 'X-2023-05',
#    'LicenseNumber': None,
#    'MiddleName': None,
#    'NickName': None,
#    'PersonId': '5D7BEB6F1EAA4334A0A1C61185676873'},
#   {'AdditionalLastName': None,
#    'Alias': 'C1-2024-S01',
#    'Birthday': None,
#    'Birthyear': 1997,
#    'ChangedAt': '2024-01-29T12:17:29.925Z',
#    'CreatedAt': '2024-01-29T12:17:29.925Z',
#    'Deceased': None,
#    'DeceasedOn': None,
#    'FirstName': 'Jürgen',
#    'Gender': 'male',
#    'GenderText': 'Male',
#    'LastName': 'C1-2024-S01',
#    'LicenseNumber': None,
#    'MiddleName': None,
#    'NickName': None,
#    'PersonId': '7143BF8C2FE44BF1ABDA10E3BAA33CCF'},
#   {'AdditionalLastName': None,
#    'Alias': 'L-2024-P005M',
#    'Birthday': None,
#    'Birthyear': 1997,
#    'ChangedAt': '2024-01-29T12:21:42.060Z',
#    'CreatedAt': '2024-01-29T12:21:42.060Z',
#    'Deceased': None,
#    'DeceasedOn': None,
#    'FirstName': 'André',
#    'Gender': 'male',
#    'GenderText': 'Male',
#    'LastName': 'L-2024-P005M',
#    'LicenseNumber': None,
#    'MiddleName': None,
#    'NickName': None,
#    'PersonId': '753D3E7DD7B646E3B44872301CF0754D'},
#   {'AdditionalLastName': None,
#    'Alias': 'C1-PFV-2024-02',
#    'Birthday': None,
#    'Birthyear': 1992,
#    'ChangedAt': '2024-01-28T11:22:29.914Z',
#    'CreatedAt': '2024-01-28T11:22:29.914Z',
#    'Deceased': None,
#    'DeceasedOn': None,
#    'FirstName': 'Chris',
#    'Gender': 'male',
#    'GenderText': 'Male',
#    'LastName': 'C1-PFV-2024-02',
#    'LicenseNumber': None,
#    'MiddleName': None,
#    'NickName': None,
#    'PersonId': 'C4502DE0576340419B5BEF056030E04D'}]}
